# %% [markdown]
# # Exploration Exercises

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import wrangle
import explore

# %%
train, validate, test = wrangle.wrangle_telco()

# %%
explore.plot_variable_pairs(train, drop_scaled_columns=False)

# %%
# several ways to round down
math.floor(3.0), math.floor(3.1), math.floor(3.9999)

int(3.0), int(3.1), int(3.999)

3.0 // 1, 3.1 // 1, 3.99999 // 1

# %%
train = explore.months_to_years(train)

# %%
explore.plot_categorical_and_continuous_vars(train, 'tenure_years', 'total_charges')

# %% [markdown]
# Applying functions to the mall customers dataset

# %%
from sklearn.model_selection import train_test_split

# %%
df = wrangle.get_mall_customer_data()

train_and_validate, test = train_test_split(df, test_size=.2, random_state=123)
train, validate = train_test_split(train_and_validate, test_size=.2, random_state=123)

train.shape, validate.shape, test.shape
# Out:
# ((128, 5), (32, 5), (40, 5))

# %%
train
# Out:
#      customer_id  gender  age  annual_income  spending_score
# 113          114    Male   19             64              46
# 55            56    Male   47             43              41
# 153          154  Female   38             78              76
# 100          101  Female   23             62              41
# 198          199    Male   32            137              18
# ..           ...     ...  ...            ...             ...
# 175          176  Female   30             88              86
# 101          102  Female   49             62              48
# 148          149  Female   34             78              22
# 99           100    Male   20             61              49
# 22            23  Female   46             25               5
#
# [128 rows x 5 columns]

# %% [markdown]
# Customer_id is an autogenerated id, correlations with it aren't useful.

# %%
explore.plot_variable_pairs(train.drop(columns='customer_id'))

# %% [markdown]
# Takeaways:
#
# - looks like a slight negative correlation between spending_score and age
# - spending score and annual income look related, but not a linear correlation (clusters?)

# %%
explore.plot_categorical_and_continuous_vars(train, 'gender', 'age')

# %% [markdown]
# Takeaway: doesn't seem to be much relationship between gender and age
